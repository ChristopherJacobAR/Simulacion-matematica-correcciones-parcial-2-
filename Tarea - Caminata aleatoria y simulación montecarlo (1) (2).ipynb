# %% [markdown]
# # Tarea - Caminata aleatoria y simulación montecarlo

# %% [markdown]
# #### 1. Simulación del movimiento browniano
#
# El movimiento browniano es el movimiento aleatorio que se observa en las partículas que se hallan en un medio fluido, como resultado de choques contra las moléculas de dicho fluido [(referencia)].
#
# [(referencia)]: https://es.wikipedia.org/wiki/Movimiento_browniano
#
# Para simular el movimiento, en lugar de usar las ecuaciones integro-diferenciales que describe Einstein, use una caminta aleatoria para los tres ejes $x$, $y$, $z$ de la siguiente forma
# $$
# W_i=W_{i-1}+X_i\sqrt{\Delta t}
# $$
# donde, $\Delta t$ es un intervalo de tiempo y
# $$
# X_i=\left\{\begin{array}{l}
# 1\\
# -1
# \end{array}\right.,
# $$
# se escoge de forma aleatoria con la misma probabilidad.
#
# Simule $10$ segundos con un $\Delta t=0.001$ y represéntelo en un gráfico 3D (Puede ver el archivo de Ejemplo 3D).

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
delta_t = 0.001
sec = 10
steps = int(sec / delta_t)
x = [0]
y = [0]
z = [0]

for i in range(steps):
    x_i = np.random.choice([1, -1])
    y_i = np.random.choice([1, -1])
    z_i = np.random.choice([1, -1])
    x.append(x[-1] + x_i * np.sqrt(delta_t))
    y.append(y[-1] + y_i * np.sqrt(delta_t))
    z.append(z[-1] + z_i * np.sqrt(delta_t))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, lw=0.5)
ax.set_title('Simulación del Movimiento Browniano')
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
plt.show()

# %% [markdown]
# #### 2. Apuesta arriesgada
#
# Un jugador, con 20 pesos de capital inicial, decide apostar a un volado (con una moneda perfectamente nivelada) la mitad de su capital si éste es mayor o igual a 6 pesos, de lo contrario, solo 2. Esto es, el capital $C_i$ en cada volado $V_i$ se describe como
# $$
# C_{i+1}=C_i+V_iA_i
# $$
# donde la apuesta es
# $$
# A_i=\left\{\begin{array}{l}
# C_i/2,\quad \mbox{si }C_i\geq 6\\
# 2,\quad \mbox{de lo contrario.}
# \end{array}\right.
# $$
#
# 1. Grafique la evolución del capital hasta quedar en cero.
# 2. Determine el número de volados promedio para quedar en quiebra usando la simulación montecarlo para 10,000 apostadores.
# 3. Muestre un histograma del número de volados.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
def apostar(cantidad):
    return cantidad / 2 if cantidad >= 6 else 2

def simular_apostador(capital_inicial):
    capital = capital_inicial
    historia_capital = [capital]
    
    while capital > 0:
        apuesta = apostar(capital)
        volado = np.random.choice(['ganar', 'perder'])
        capital = capital + apuesta if volado == 'ganar' else capital - apuesta
        historia_capital.append(capital)
    
    return historia_capital

num_apostadores = 10000
resultados = []

for i in range(num_apostadores):
    historia = simular_apostador(20)
    resultados.append(len(historia) - 1)

df_resultados = pd.DataFrame(resultados, columns=['Volados'])

plt.figure(figsize=(10, 6))
plt.plot(simular_apostador(20))
plt.title('Evolución del Capital de un Apostador')
plt.xlabel('Número de Volados')
plt.ylabel('Capital')
plt.grid(True)
plt.show()

promedio_volados = np.mean(resultados)
print(f"El número promedio de volados para quedar en quiebra es: {promedio_volados:.2f}")

plt.figure(figsize=(10, 6))
plt.hist(df_resultados['Volados'], bins=30, color='blue', alpha=0.7)
plt.title('Histograma del Número de Volados para Quedar en Quiebra')
plt.xlabel('Número de Volados')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
# Out:
# El número promedio de volados para quedar en quiebra es: 26.34
